# %%
import pandas as pd

train_data = pd.read_csv('Train.csv')
test_data = pd.read_csv('Test.csv')

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11879 entries, 0 to 11878
# Data columns (total 27 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Id                                        11879 non-null  int64
#  1   Sex                                       10449 non-null  object
#  2   Sex Code                                  10426 non-null  object
#  3   State                                     10482 non-null  object
#  4   State Code                                11879 non-null  float64
#  5   Year                                      7407 non-null   float64
#  6   Year Code                                 7352 non-null   float64
#  7   Ten-Year Age Groups                       10379 non-null  object
#  8   Ten-Year Age Groups Code                  10423 non-null  object
#  9   % of Total Deaths                         11879 non-null  float64
# ...

# %%
train_data.drop(["Id"] , inplace=True , axis=1)
train_data.info() #State code
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11879 entries, 0 to 11878
# Data columns (total 26 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Sex                                       10449 non-null  object
#  1   Sex Code                                  10426 non-null  object
#  2   State                                     10482 non-null  object
#  3   State Code                                11879 non-null  float64
#  4   Year                                      7407 non-null   float64
#  5   Year Code                                 7352 non-null   float64
#  6   Ten-Year Age Groups                       10379 non-null  object
#  7   Ten-Year Age Groups Code                  10423 non-null  object
#  8   % of Total Deaths                         11879 non-null  float64
#  9   Population                                10493 non-null  object
# ...
